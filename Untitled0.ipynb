# %% [markdown]
# <a href="https://colab.research.google.com/github/rikzz0000-svg/VALORANT/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=10
print (type(A))
# Out:
# <class 'int'>

# %%
b=10.5
print (type(b))
# Out:
# <class 'float'>

# %%
A='people'
print (type(A))
# Out:
# <class 'str'>

# %%
A= False
print (type(A))
# Out:
# <class 'bool'>

# %%
l = [1, 2, 3, 4]
print (type(l))
# Out:
# <class 'list'>

# %%
s= {1, 2, 3, 4}
print (type(s))
# Out:
# <class 'set'>

# %%
t = (10.0, 20.0)
print (type(t))
# Out:
# <class 'tuple'>

# %%
d={"name": "Alice", "age": 30}
print (type(d))
# Out:
# <class 'dict'>
